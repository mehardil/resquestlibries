# %%
import requests
params = {'page': '2'}
x = requests.get('https://quotes.toscrape.com?page =2', params=params)
print(x.headers)
# Out:
# {'Date': 'Mon, 23 Jan 2023 06:40:08 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Strict-Transport-Security': 'max-age=0; includeSubDomains; preload', 'Content-Encoding': 'br'}

# %%
print(x.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta charset="UTF-8">
# 	<title>Quotes to Scrape</title>
#     <link rel="stylesheet" href="/static/bootstrap.min.css">
#     <link rel="stylesheet" href="/static/main.css">
# </head>
# <body>
#     <div class="container">
#         <div class="row header-box">
#             <div class="col-md-8">
#                 <h1>
#                     <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#                 </h1>
#             </div>
#             <div class="col-md-4">
#                 <p>
#
#                     <a href="/login">Login</a>
#
#                 </p>
#             </div>
#         </div>
#
#
# <div class="row">
#     <div class="col-md-8">
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
#         <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# ...

# %%
import requests

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_content, "lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Quotes to Scrape
#   </title>
#   <link href="/static/bootstrap.min.css" rel="stylesheet"/>
#   <link href="/static/main.css" rel="stylesheet"/>
#  </head>
#  <body>
#   <div class="container">
#    <div class="row header-box">
#     <div class="col-md-8">
#      <h1>
#       <a href="/" style="text-decoration: none">
#        Quotes to Scrape
#       </a>
#      </h1>
#     </div>
#     <div class="col-md-4">
#      <p>
#       <a href="/login">
#        Login
#       </a>
#      </p>
#     </div>
#    </div>
#    <div class="row">
#     <div class="col-md-8">
#      <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#       <span class="text" itemprop="text">
# ...

# %%
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
soup.find_all('div')
# Out:
# [<div class="container">
#  <div class="row header-box">
#  <div class="col-md-8">
#  <h1>
#  <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#  </h1>
#  </div>
#  <div class="col-md-4">
#  <p>
#  <a href="/login">Login</a>
#  </p>
#  </div>
#  </div>
#  <div class="row">
#  <div class="col-md-8">
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# ...

# %%
soup.p
# Out:
# <p>
# <a href="/login">Login</a>
# </p>

# %%
soup.find_all('p')
# Out:
# [<p>
#  <a href="/login">Login</a>
#  </p>,
#  <p class="text-muted">
#                  Quotes by: <a href="https://www.goodreads.com/quotes">GoodReads.com</a>
#  </p>,
#  <p class="copyright">
#                  Made with <span class="sh-red">❤</span> by <a href="https://scrapinghub.com">Scrapinghub</a>
#  </p>]

# %%
link = []
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# <a href="/login">Login</a>
# <a href="/author/Marilyn-Monroe">(about)</a>
# <a class="tag" href="/tag/friends/page/1/">friends</a>
# <a class="tag" href="/tag/heartbreak/page/1/">heartbreak</a>
# <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>
# <a class="tag" href="/tag/life/page/1/">life</a>
# <a class="tag" href="/tag/love/page/1/">love</a>
# <a class="tag" href="/tag/sisters/page/1/">sisters</a>
# <a href="/author/J-K-Rowling">(about)</a>
# <a class="tag" href="/tag/courage/page/1/">courage</a>
# <a class="tag" href="/tag/friends/page/1/">friends</a>
# <a href="/author/Albert-Einstein">(about)</a>
# <a class="tag" href="/tag/simplicity/page/1/">simplicity</a>
# <a class="tag" href="/tag/understand/page/1/">understand</a>
# <a href="/author/Bob-Marley">(about)</a>
# <a class="tag" href="/tag/love/page/1/">love</a>
# <a href="/author/Dr-Seuss">(about)</a>
# ...

# %%
dict ={}
j =0
for link in soup.find_all('div'):
    dict[j] = [link["class"]]
    j =j + 1
print(dict)
# Out:
# {0: [['container']], 1: [['row', 'header-box']], 2: [['col-md-8']], 3: [['col-md-4']], 4: [['row']], 5: [['col-md-8']], 6: [['quote']], 7: [['tags']], 8: [['quote']], 9: [['tags']], 10: [['quote']], 11: [['tags']], 12: [['quote']], 13: [['tags']], 14: [['quote']], 15: [['tags']], 16: [['quote']], 17: [['tags']], 18: [['quote']], 19: [['tags']], 20: [['quote']], 21: [['tags']], 22: [['quote']], 23: [['tags']], 24: [['quote']], 25: [['tags']], 26: [['col-md-4', 'tags-box']], 27: [['container']]}

# %%
import pandas as pd

# %%
import pandas as pd
df2 = pd.DataFrame.from_dict(dicts, orient='index', columns=['price'])

df
# Out:
#                  classes
# 0            [container]
# 1      [row, header-box]
# 2             [col-md-8]
# 3             [col-md-4]
# 4                  [row]
# 5             [col-md-8]
# 6                [quote]
# 7                 [tags]
# 8                [quote]
# 9                 [tags]
# 10               [quote]
# 11                [tags]
# 12               [quote]
# 13                [tags]
# 14               [quote]
# 15                [tags]
# 16               [quote]
# 17                [tags]
# 18               [quote]
# 19                [tags]
# 20               [quote]
# 21                [tags]
# 22               [quote]
# 23                [tags]
# 24               [quote]
# 25                [tags]
# 26  [col-md-4, tags-box]
# 27           [container]

# %%
df2.to_csv('new01.csv',index=False)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10168\3593513809.py in <module>
#       2
#       3 for row in soup.find_all('div'):
# ----> 4     d = dict()
#       5
#       6     d['name'] = row.select_one('.source-title').text.strip()
#
# TypeError: 'dict' object is not callable

# %%
import requests
params = {'page': '2'}
x = requests.get("https://quotes.toscrape.com/page/2/")
print(x.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta charset="UTF-8">
# 	<title>Quotes to Scrape</title>
#     <link rel="stylesheet" href="/static/bootstrap.min.css">
#     <link rel="stylesheet" href="/static/main.css">
# </head>
# <body>
#     <div class="container">
#         <div class="row header-box">
#             <div class="col-md-8">
#                 <h1>
#                     <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#                 </h1>
#             </div>
#             <div class="col-md-4">
#                 <p>
#
#                     <a href="/login">Login</a>
#
#                 </p>
#             </div>
#         </div>
#
#
# <div class="row">
#     <div class="col-md-8">
#
#     <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">
# ...

# %%
dict ={}
j =0
for link in soup.find_all('p'):
    dict[j] = [link]
    j =j + 1
print(dict)
# Out:
# {0: [<p>
# <a href="/login">Login</a>
# </p>], 1: [<p class="text-muted">
#                 Quotes by: <a href="https://www.goodreads.com/quotes">GoodReads.com</a>
# </p>], 2: [<p class="copyright">
#                 Made with <span class="sh-red">❤</span> by <a href="https://scrapinghub.com">Scrapinghub</a>
# </p>]}

# %%
dict
# Out:
# {0: [<p>
#   <a href="/login">Login</a>
#   </p>],
#  1: [<p class="text-muted">
#                   Quotes by: <a href="https://www.goodreads.com/quotes">GoodReads.com</a>
#   </p>],
#  2: [<p class="copyright">
#                   Made with <span class="sh-red">❤</span> by <a href="https://scrapinghub.com">Scrapinghub</a>
#   </p>]}

# %%
df3 = pd.DataFrame.from_dict(dict, orient='index', columns=['classes'])
df3
# Out:
#                                              classes
# 0                                  [\n, [Login], \n]
# 1  [\n                Quotes by: , [GoodReads.com...
# 2  [\n                Made with , [❤],  by , [Scr...

# %%
df2.insert(1, column = "price", value = df3)

# %%
df2
# Out:
#                  classes                                              price
# 0            [container]                                  [\n, [Login], \n]
# 1      [row, header-box]  [\n                Quotes by: , [GoodReads.com...
# 2             [col-md-8]  [\n                Made with , [❤],  by , [Scr...
# 3             [col-md-4]                                                NaN
# 4                  [row]                                                NaN
# 5             [col-md-8]                                                NaN
# 6                [quote]                                                NaN
# 7                 [tags]                                                NaN
# 8                [quote]                                                NaN
# 9                 [tags]                                                NaN
# 10               [quote]                                                NaN
# ...

# %%
dict
# Out:
# {0: [<p>
#   <a href="/login">Login</a>
#   </p>],
#  1: [<p class="text-muted">
#                   Quotes by: <a href="https://www.goodreads.com/quotes">GoodReads.com</a>
#   </p>],
#  2: [<p class="copyright">
#                   Made with <span class="sh-red">❤</span> by <a href="https://scrapinghub.com">Scrapinghub</a>
#   </p>]}

# %%
//*[@id="toplists"]/div[3]/table/tbody/tr[76]/td[5]
# Out:
#   File "C:\Users\Mehardil\AppData\Local\Temp\ipykernel_8160\838637913.py", line 1
#     //*[@id="toplists"]/div[3]/table/tbody/tr[76]/td[5]
#     ^
# SyntaxError: invalid syntax

# %%
//*[@id="toplists"]/div[3]/table/tbody/tr[i]

# %%
//*[@id="toplists"]/div[1]/div/a[4]

# %%
//*[@id="toplists"]/div[3]/table/tbody/tr[1]/td[4]

# %%
//*[@id="toplists"]/div[3]/table/tbody/tr[100]/td[1]

# %%
//*[@id="toplists"]/div[3]/table/tbody/tr[100]/td[4]
